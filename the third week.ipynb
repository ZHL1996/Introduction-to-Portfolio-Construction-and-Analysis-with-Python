# %%
import EDHEC_risk_kit as erk
import pandas as pd
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %%
ind_firms = erk.get_ind_nfirms()

# %%
ind_size = erk.get_ind_size()
ind_returns = erk.get_ind_returns()

# %%
ind_firms.shape
# Out:
# (1110, 30)

# %%
ind_returns.shape
# Out:
# (1110, 30)

# %%
ind_size.shape
# Out:
# (1110, 30)

# %%
a = pd.DataFrame({'ind_firms':ind_firms.shape,'ind_returns':ind_returns.shape,'ind_size':ind_size.shape})
a
# Out:
#    ind_firms  ind_returns  ind_size
# 0       1110         1110      1110
# 1         30           30        30

# %%
ind_mktcap = ind_firms * ind_size
ind_mktcap
# Out:
#               Food       Beer      Smoke      Games     Books      Hshld  \
# 1926-07    1547.14      21.36     955.52     184.87     24.04     178.16
# 1926-08    1552.30      20.25     967.52     190.19     26.66     177.04
# 1926-09    1591.00      25.74    1024.48     191.10     29.34     169.44
# 1926-10    1597.02      26.76    1030.72     201.32     28.84     169.84
# 1926-11    1542.84      25.86    1041.28     191.66     31.58     161.12
# ...            ...        ...        ...        ...       ...        ...
# 2018-08  655086.88  248864.40  246251.37  359322.24  34986.00  436335.51
# 2018-09  650961.36  243994.20  232888.44  369482.88  33346.32  447087.81
# 2018-10  638821.15  243073.92  242110.77  366408.00  32533.41  451597.38
# 2018-11  644666.55  239183.23  261239.37  307688.02  30333.87  446944.29
# 2018-12  658749.30  252813.22  239218.44  305508.10  31240.02  475395.96
#
#              Clths        Hlth      Chems     Txtls  ...       Telcm  \
# 1926-07     220.32      178.64     979.03     80.34  ...     1751.80
# 1926-08     237.96      180.60    1056.21     80.60  ...     1766.35
# 1926-09     231.48      187.11    1114.01     87.23  ...     1804.80
# 1926-10     228.36      188.09    1163.99     88.66  ...     1820.80
# 1926-11     228.36      185.78    1106.02     88.92  ...     1818.70
# ...            ...         ...        ...       ...  ...         ...
# 2018-08  291114.00  3101280.74  527004.08  18460.08  ...  1194867.48
# 2018-09  305995.50  3233033.92  525412.88  19156.88  ...  1229361.27
# 2018-10  309179.15  3288588.12  462370.35  17928.00  ...  1250164.08
# 2018-11  277819.13  2990934.10  403502.22  13304.88  ...  1237481.19
# 2018-12  274388.43  3171655.62  422096.40  13689.28  ...  1268109.60
#
#               Servs       BusEq      Paper      Trans      Whlsl       Rtail  \
# 1926-07       40.80      396.90     212.10    4951.34       2.38     1539.45
# 1926-08       44.25      404.18     227.16    5031.26       1.80     1536.81
# 1926-09       45.15      417.27     220.92    5255.48       1.90     1521.63
# 1926-10       45.90      416.64     208.62    5241.42       1.76     1522.95
# 1926-11       44.67      411.18     196.80    5087.50       1.48     1485.99
# ...             ...         ...        ...        ...        ...         ...
# 2018-08  4823187.60  3246634.04  302188.62  702401.00  329067.65  2282934.94
# 2018-09  5069913.20  3562212.72  299831.35  720451.90  340645.57  2486473.99
# 2018-10  5043137.32  3546678.80  298376.14  727665.40  330246.60  2500872.76
# 2018-11  4559456.44  3258043.60  265650.12  656465.31  303814.75  2244299.82
# 2018-12  4610617.44  3063730.80  286180.92  689981.72  313004.10  2224518.80
#
#              Meals         Fin       Other
# 1926-07      64.92      225.96       97.00
# 1926-08      66.00      226.56      102.04
# 1926-09      65.64      236.04      108.84
# 1926-10      64.80      232.32      104.64
# 1926-11      61.98      220.20       95.76
# ...            ...         ...         ...
# 2018-08  428784.93  4930872.78  1432052.70
# 2018-09  442374.34  5037628.51  1473543.50
# 2018-10  453366.32  4930387.44  1488960.20
# 2018-11  445210.94  4583277.60  1399224.32
# 2018-12  468870.00  4704335.73  1444693.58
#
# [1110 rows x 30 columns]

# %%
total_mktcap = ind_mktcap.sum(axis=1)
total_mktcap
# Out:
# 1926-07       26657.94
# 1926-08       27436.34
# 1926-09       28060.41
# 1926-10       28057.23
# 1926-11       27198.40
#               ...
# 2018-08    29949911.36
# 2018-09    30990177.46
# 2018-10    30918505.63
# 2018-11    28463290.74
# 2018-12    28851651.12
# Freq: M, Length: 1110, dtype: float64

# %%
total_mktcap.plot(figsize = (12,6));

# %%
ind_capweights = ind_mktcap.divide(total_mktcap,axis=0)
ind_capweights
# Out:
#              Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# 1926-07  0.058037  0.000801  0.035844  0.006935  0.000902  0.006683  0.008265
# 1926-08  0.056578  0.000738  0.035264  0.006932  0.000972  0.006453  0.008673
# 1926-09  0.056699  0.000917  0.036510  0.006810  0.001046  0.006038  0.008249
# 1926-10  0.056920  0.000954  0.036736  0.007175  0.001028  0.006053  0.008139
# 1926-11  0.056725  0.000951  0.038285  0.007047  0.001161  0.005924  0.008396
# ...           ...       ...       ...       ...       ...       ...       ...
# 2018-08  0.021873  0.008309  0.008222  0.011997  0.001168  0.014569  0.009720
# 2018-09  0.021005  0.007873  0.007515  0.011923  0.001076  0.014427  0.009874
# 2018-10  0.020661  0.007862  0.007831  0.011851  0.001052  0.014606  0.010000
# 2018-11  0.022649  0.008403  0.009178  0.010810  0.001066  0.015702  0.009761
# 2018-12  0.022832  0.008763  0.008291  0.010589  0.001083  0.016477  0.009510
#
#              Hlth     Chems     Txtls  ...     Telcm     Servs     BusEq  \
# 1926-07  0.006701  0.036726  0.003014  ...  0.065714  0.001531  0.014889
# 1926-08  0.006583  0.038497  0.002938  ...  0.064380  0.001613  0.014732
# 1926-09  0.006668  0.039700  0.003109  ...  0.064318  0.001609  0.014870
# 1926-10  0.006704  0.041486  0.003160  ...  0.064896  0.001636  0.014850
# 1926-11  0.006831  0.040665  0.003269  ...  0.066868  0.001642  0.015118
# ...           ...       ...       ...  ...       ...       ...       ...
# 2018-08  0.103549  0.017596  0.000616  ...  0.039896  0.161042  0.108402
# 2018-09  0.104324  0.016954  0.000618  ...  0.039669  0.163597  0.114947
# 2018-10  0.106363  0.014954  0.000580  ...  0.040434  0.163111  0.114711
# 2018-11  0.105080  0.014176  0.000467  ...  0.043476  0.160187  0.114465
# 2018-12  0.109930  0.014630  0.000474  ...  0.043953  0.159804  0.106189
#
#             Paper     Trans     Whlsl     Rtail     Meals       Fin     Other
# 1926-07  0.007956  0.185736  0.000089  0.057748  0.002435  0.008476  0.003639
# 1926-08  0.008280  0.183379  0.000066  0.056014  0.002406  0.008258  0.003719
# 1926-09  0.007873  0.187292  0.000068  0.054227  0.002339  0.008412  0.003879
# 1926-10  0.007436  0.186812  0.000063  0.054280  0.002310  0.008280  0.003730
# 1926-11  0.007236  0.187051  0.000054  0.054635  0.002279  0.008096  0.003521
# ...           ...       ...       ...       ...       ...       ...       ...
# 2018-08  0.010090  0.023453  0.010987  0.076225  0.014317  0.164637  0.047815
# 2018-09  0.009675  0.023248  0.010992  0.080234  0.014275  0.162556  0.047549
# 2018-10  0.009650  0.023535  0.010681  0.080886  0.014663  0.159464  0.048158
# 2018-11  0.009333  0.023064  0.010674  0.078849  0.015642  0.161024  0.049159
# 2018-12  0.009919  0.023915  0.010849  0.077102  0.016251  0.163053  0.050073
#
# [1110 rows x 30 columns]

# %%
ind_capweights['1926'].sum(axis=1)
# Out:
# 1926-07    1.0
# 1926-08    1.0
# 1926-09    1.0
# 1926-10    1.0
# 1926-11    1.0
# 1926-12    1.0
# Freq: M, dtype: float64

# %%
ind_capweights[['Fin','Steel']].plot(figsize=(12,6));

# %%
total_market_return = (ind_capweights * ind_returns).sum(axis=1)
total_market_return.plot();

# %%
total_market_index = erk.drawdown(total_market_return).wealth
total_market_index.plot(figsize=(12,6),title = "Total Capweighted Market Index through 1926-2018");

# %%
total_market_index["1980":].plot(figsize = (10,6));
total_market_index["1980":].rolling(window=36).mean().plot(); # rolling average

# %%
tmi_tr36rets = total_market_return.rolling(window = 36). aggregate(erk.an_ret, p = 12)
tmi_tr36rets.plot(figsize = (12,6),label = "tr36 mo returns",legend = True);
total_market_return.plot(label = "returns",legend = True);

# %%
ts_corr = ind_returns.rolling(window=36).corr()
ts_corr.dropna()
# Out:
#                    Food      Beer     Smoke     Games     Books     Hshld  \
# 1929-06 Food   1.000000  0.629628  0.596971  0.675709  0.281427  0.729475
#         Beer   0.629628  1.000000  0.346617  0.328484  0.349330  0.458642
#         Smoke  0.596971  0.346617  1.000000  0.317146  0.086412  0.424323
#         Games  0.675709  0.328484  0.317146  1.000000  0.198889  0.715495
#         Books  0.281427  0.349330  0.086412  0.198889  1.000000  0.174562
# ...                 ...       ...       ...       ...       ...       ...
# 2018-12 Whlsl  0.474948  0.356983  0.122672  0.510425  0.803362  0.419280
#         Rtail  0.517856  0.406107  0.030283  0.676464  0.636320  0.358336
#         Meals  0.370187  0.385483  0.122007  0.301516  0.520649  0.308216
#         Fin    0.298823  0.192706  0.027593  0.480276  0.694812  0.162690
#         Other  0.436952  0.376565  0.224010  0.331829  0.558072  0.390610
#
#                   Clths      Hlth     Chems     Txtls  ...     Telcm  \
# 1929-06 Food   0.490230  0.676560  0.716603  0.617928  ...  0.623219
#         Beer   0.203686  0.532148  0.444421  0.640713  ...  0.426311
#         Smoke  0.155380  0.398125  0.452359  0.601743  ...  0.299186
#         Games  0.303105  0.513858  0.642301  0.439412  ...  0.550541
#         Books  0.435561  0.364148  0.114258  0.174108  ...  0.282757
# ...                 ...       ...       ...       ...  ...       ...
# 2018-12 Whlsl  0.570071  0.739764  0.785796  0.634197  ...  0.648092
#         Rtail  0.676598  0.714933  0.626034  0.634202  ...  0.562238
#         Meals  0.302176  0.416193  0.520023  0.491726  ...  0.406184
#         Fin    0.425899  0.658468  0.760151  0.577090  ...  0.420863
#         Other  0.467099  0.645035  0.712511  0.520953  ...  0.607868
#
#                   Servs     BusEq     Paper     Trans     Whlsl     Rtail  \
# 1929-06 Food   0.497310  0.660446  0.643028  0.735555  0.444707  0.795404
#         Beer   0.281562  0.350989  0.504010  0.504435  0.516265  0.426823
#         Smoke  0.337226  0.428761  0.192498  0.563923  0.254963  0.519246
#         Games  0.406675  0.319347  0.350967  0.529214  0.287682  0.534292
#         Books  0.139979  0.189726  0.308485  0.252343  0.028740  0.238301
# ...                 ...       ...       ...       ...       ...       ...
# 2018-12 Whlsl  0.567395  0.543362  0.764252  0.829185  1.000000  0.744842
#         Rtail  0.762616  0.628246  0.656510  0.630615  0.744842  1.000000
#         Meals  0.444629  0.399438  0.627113  0.663358  0.643879  0.616947
#         Fin    0.585418  0.517947  0.670936  0.760730  0.746480  0.611883
#         Other  0.460322  0.434487  0.773798  0.756961  0.767652  0.619918
#
#                   Meals       Fin     Other
# 1929-06 Food   0.684892  0.712037  0.724775
#         Beer   0.498461  0.526614  0.468640
#         Smoke  0.244318  0.461119  0.490210
#         Games  0.397446  0.663349  0.567514
#         Books  0.319734  0.293167  0.465276
# ...                 ...       ...       ...
# 2018-12 Whlsl  0.643879  0.746480  0.767652
#         Rtail  0.616947  0.611883  0.619918
#         Meals  1.000000  0.502563  0.605226
#         Fin    0.502563  1.000000  0.734837
#         Other  0.605226  0.734837  1.000000
#
# [32250 rows x 30 columns]

# %%
ind_returns.head()
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals     Fin   Other
# 1926-07  0.0007  0.0187  0.0037  0.0520
# 1926-08 -0.0075 -0.0013  0.0446  0.0676
# 1926-09  0.0025 -0.0056 -0.0123 -0.0386
# 1926-10 -0.0220 -0.0411 -0.0516 -0.0849
# 1926-11  0.0652  0.0433  0.0224  0.0400
#
# [5 rows x 30 columns]

# %%
ts_corr.index.names = ["date","industry"]
ts_corr.tail()
# Out:
#                       Food      Beer     Smoke     Games     Books     Hshld  \
# date    industry
# 2018-12 Whlsl     0.474948  0.356983  0.122672  0.510425  0.803362  0.419280
#         Rtail     0.517856  0.406107  0.030283  0.676464  0.636320  0.358336
#         Meals     0.370187  0.385483  0.122007  0.301516  0.520649  0.308216
#         Fin       0.298823  0.192706  0.027593  0.480276  0.694812  0.162690
#         Other     0.436952  0.376565  0.224010  0.331829  0.558072  0.390610
#
#                      Clths      Hlth     Chems     Txtls  ...     Telcm  \
# date    industry                                          ...
# 2018-12 Whlsl     0.570071  0.739764  0.785796  0.634197  ...  0.648092
#         Rtail     0.676598  0.714933  0.626034  0.634202  ...  0.562238
#         Meals     0.302176  0.416193  0.520023  0.491726  ...  0.406184
#         Fin       0.425899  0.658468  0.760151  0.577090  ...  0.420863
#         Other     0.467099  0.645035  0.712511  0.520953  ...  0.607868
#
#                      Servs     BusEq     Paper     Trans     Whlsl     Rtail  \
# date    industry
# 2018-12 Whlsl     0.567395  0.543362  0.764252  0.829185  1.000000  0.744842
#         Rtail     0.762616  0.628246  0.656510  0.630615  0.744842  1.000000
#         Meals     0.444629  0.399438  0.627113  0.663358  0.643879  0.616947
#         Fin       0.585418  0.517947  0.670936  0.760730  0.746480  0.611883
#         Other     0.460322  0.434487  0.773798  0.756961  0.767652  0.619918
#
#                      Meals       Fin     Other
# date    industry
# 2018-12 Whlsl     0.643879  0.746480  0.767652
#         Rtail     0.616947  0.611883  0.619918
#         Meals     1.000000  0.502563  0.605226
#         Fin       0.502563  1.000000  0.734837
#         Other     0.605226  0.734837  1.000000
#
# [5 rows x 30 columns]

# %%
ind_tr36corr = ts_corr.groupby(level = 'date').apply(lambda cormat: cormat.values.mean())
ind_tr36corr.plot(figsize = (12,6));

# %%
tmi_tr36rets.plot(figsize = (12,6),label = "tr36 mo returns",legend = True);
ind_tr36corr.plot(label = "tr36 mo corr",legend = True,secondary_y = True);

# %%
tmi_tr36rets["2007":].plot(label = "tr36 mo returns",legend = True,figsize = (12,6));
ind_tr36corr["2007":].plot(label = "tr36 mo corr",legend = True,secondary_y = True);

# %%
tmi_tr36rets.corr(ind_tr36corr)
# Out:
# -0.2801006506288413

# %%
total_market_return = (ind_capweights * ind_returns).sum(axis=1)
total_market_return
# Out:
# 1926-07    0.031375
# 1926-08    0.028957
# 1926-09    0.005566
# 1926-10   -0.028504
# 1926-11    0.028039
#              ...
# 2018-08    0.036951
# 2018-09    0.002108
# 2018-10   -0.074292
# 2018-11    0.019003
# 2018-12   -0.092911
# Freq: M, Length: 1110, dtype: float64

# %%
risky_r = ind_returns["2000":][["Steel","Fin","Beer"]]
risky_r.shape
# Out:
# (228, 3)

# %% [markdown]
# # CPPI Strategy

# %%
safe_r = pd.DataFrame().reindex_like(risky_r) # 自动copy risky_r 的shape
safe_r.shape
# Out:
# (228, 3)

# %%
safe_r[:] = 0.03/12
start = 1000
floor = 0.8

# %% [markdown]
# Cusion = asset value - floor
# compute allocation of risky and safe assets: m*risk_budget
# recompute the asset value based on the returns

# %%
def compound1(r):
    return (1+r).prod() - 1

def compound2(r):
    return np.expm1(np.log1p(r).sum())

# %%
compound1(risky_r)
# Out:
# Steel   -0.051696
# Fin      1.773937
# Beer     3.361349
# dtype: float64

# %%
compound2(risky_r)
# Out:
# Steel   -0.051696
# Fin      1.773937
# Beer     3.361349
# dtype: float64

# %%
# %timeit compound1(risky_r)
# Out:
# 212 µs ± 1.42 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit %timeit compound2(risky_r)
# Out:
# 186 µs ± 1.8 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 186 µs ± 3.03 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 185 µs ± 988 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 186 µs ± 2.91 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 184 µs ± 959 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 185 µs ± 623 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 183 µs ± 1.14 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 185 µs ± 813 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 15 s ± 70.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
dates = risky_r.index 
n_steps = len(dates)
account_value = start
floor_value = floor * start
m = 3

# %%
account_history = pd.DataFrame().reindex_like(risky_r)
cusion_history = pd.DataFrame().reindex_like(risky_r)
risky_w_history = pd.DataFrame().reindex_like(risky_r)

# %%
safe_r[:] = 0.03/12
start = 1000
floor = 0.8

dates = risky_r.index 
n_steps = len(dates)
account_value = start
floor_value = floor * start
m = 3

for step in range(n_steps):
    cusion = (account_value - floor_value)/ account_value
    risk_w = m*cusion
    risk_w = np.minimum(risk_w,1)
    risk_w = np.maximum (risk_w,0)
    safe_w = 1-risk_w
    risky_alloc = account_value*risk_w
    safe_alloc = account_value * safe_w
    # update account value for time step
    account_value = risky_alloc*(1+risky_r.iloc[step])+safe_alloc*(1+safe_r.iloc[step])
    # store the result
    cusion_history.iloc[step] = cusion
    risky_w_history.iloc[step] = risk_w
    account_history.iloc[step] = account_value

# %%
cusion_history.head()
# Out:
#             Steel       Fin      Beer
# 2000-01  0.200000  0.200000  0.200000
# 2000-02  0.187306  0.179049  0.189726
# 2000-03  0.218210  0.140864  0.133234
# 2000-04  0.236317  0.198547  0.134982
# 2000-05  0.232304  0.178584  0.148930

# %%
account_history.plot();

# %%
risky_wealth = (1+risky_r).cumprod()*start
risky_wealth.plot();

# %%
ax = account_history['Beer'].plot(figsize = (12,6),color = 'green')
risky_wealth['Beer'].plot(ax=ax, style = "k:")
ax.axhline(y = floor_value, color='r',linestyle='--');

# %%
risky_w_history.plot();

# %%
ind = "Fin"
ax = account_history[ind].plot(figsize = (12,6),color = 'blue')
risky_wealth[ind].plot(ax=ax, style = "k:")
ax.axhline(y = floor_value, color='r',linestyle='--');

# %%
ind = "Steel"
ax = account_history[ind].plot(figsize = (12,6),color = 'blue')
risky_wealth[ind].plot(ax=ax, style = "k:")
ax.axhline(y = floor_value, color='r',linestyle='--');

# %%
def run_cppi(risky_r,safe_r=None, start=1000,floor=0.8,risk_free_rate=0.03):
    dates = risky_r.index 
    n_steps = len(dates)
    account_value = start
    floor_value = floor * start
    m = 3
    if isinstance(risky_r, pd.Series):
        risky_r = pd.DataFrame(risky_r, columns=["R"])    
    if safe_r is None:
        safe_r=pd.DataFrame().reindex_like(risky_r)
        safe_r.values[:] =  risk_free_rate/12     
    account_history = pd.DataFrame().reindex_like(risky_r)
    cusion_history = pd.DataFrame().reindex_like(risky_r)
    risky_w_history = pd.DataFrame().reindex_like(risky_r) 
    for step in range(n_steps):
        cusion = (account_value - floor_value)/ account_value
        risk_w = m*cusion
        risk_w = np.minimum(risk_w,1)
        risk_w = np.maximum (risk_w,0)
        safe_w = 1-risk_w
        risky_alloc = account_value*risk_w
        safe_alloc = account_value * safe_w
        # update account value for time step
        account_value = risky_alloc*(1+risky_r.iloc[step])+safe_alloc*(1+safe_r.iloc[step])
        # store the result
        cusion_history.iloc[step] = cusion
        risky_w_history.iloc[step] = risk_w
        account_history.iloc[step] = account_value
    risky_wealth = start * (1+risky_r).cumprod()
    brack = {'wealth':account_history,'risky_wealth':risky_wealth,'risk_budget':cusion_history,'risk_allocation':risky_w_history,
            'm':m,'start':start,'floor':floor,'risky_r':risky_r,'safe_r':safe_r}
    return brack

# %%
run_cppi(risky_r)
# Out:
# {'wealth':                Steel          Fin         Beer
#  2000-01   984.380000   974.480000   987.320000
#  2000-02  1023.292876   931.167544   922.971256
#  2000-03  1047.555176   998.187296   924.835988
#  2000-04  1042.079009   973.927479   939.993701
#  2000-05  1007.137753  1001.460033   991.145489
#  ...              ...          ...          ...
#  2018-08  1078.784329  2461.732061  4155.508933
#  2018-09  1073.786842  2414.220632  4163.404400
#  2018-10   979.057951  2282.645608  4098.038951
#  2018-11   964.047446  2348.614066  4335.315406
#  2018-12   892.488571  2079.932617  3915.223343
#
#  [228 rows x 3 columns],
#  'risky_wealth':                Steel          Fin         Beer
#  2000-01   972.300000   955.800000   977.200000
#  2000-02  1038.805320   874.652580   863.453920
#  2000-03  1075.059626  1020.632096   864.576410
#  2000-04  1066.029125   977.255232   896.392822
#  2000-05  1013.580492  1026.704346  1002.794650
#  ...              ...          ...          ...
#  2018-08  1306.624224  3283.129665  4629.014147
#  2018-09  1297.869842  3219.765263  4637.809274
#  2018-10  1147.187153  3044.288056  4564.995669
#  2018-11  1112.771539  3132.267981  4829.308918
#  2018-12   948.303905  2773.936524  4361.348884
#
#  [228 rows x 3 columns],
#  'risk_budget':             Steel       Fin      Beer
#  2000-01  0.200000  0.200000  0.200000
#  2000-02  0.187306  0.179049  0.189726
#  2000-03  0.218210  0.140864  0.133234
#  2000-04  0.236317  0.198547  0.134982
#  2000-05  0.232304  0.178584  0.148930
#  ...           ...       ...       ...
#  2018-08  0.278101  0.667064  0.811065
#  2018-09  0.258425  0.675026  0.807484
#  2018-10  0.254973  0.668630  0.807850
#  2018-11  0.182888  0.649529  0.804785
#  2018-12  0.170165  0.659374  0.815469
#
#  [228 rows x 3 columns],
#  'risk_allocation':             Steel       Fin      Beer
#  2000-01  0.600000  0.600000  0.600000
#  2000-02  0.561917  0.537148  0.569177
#  2000-03  0.654630  0.422591  0.399702
#  2000-04  0.708951  0.595642  0.404945
#  2000-05  0.696912  0.535751  0.446791
#  ...           ...       ...       ...
#  2018-08  0.834304  1.000000  1.000000
#  2018-09  0.775274  1.000000  1.000000
#  2018-10  0.764920  1.000000  1.000000
#  2018-11  0.548664  1.000000  1.000000
#  2018-12  0.510496  1.000000  1.000000
#
#  [228 rows x 3 columns],
#  'm': 3,
#  'start': 1000,
#  'floor': 0.8,
#  'risky_r':           Steel     Fin    Beer
#  2000-01 -0.0277 -0.0442 -0.0228
#  2000-02  0.0684 -0.0849 -0.1164
#  2000-03  0.0349  0.1669  0.0013
#  2000-04 -0.0084 -0.0425  0.0368
#  2000-05 -0.0492  0.0506  0.1187
#  ...         ...     ...     ...
#  2018-08 -0.0323  0.0245 -0.0186
#  2018-09 -0.0067 -0.0193  0.0019
#  2018-10 -0.1161 -0.0545 -0.0157
#  2018-11 -0.0300  0.0289  0.0579
#  2018-12 -0.1478 -0.1144 -0.0969
#
#  [228 rows x 3 columns],
#  'safe_r':           Steel     Fin    Beer
#  2000-01  0.0025  0.0025  0.0025
#  2000-02  0.0025  0.0025  0.0025
#  2000-03  0.0025  0.0025  0.0025
#  2000-04  0.0025  0.0025  0.0025
#  2000-05  0.0025  0.0025  0.0025
#  ...         ...     ...     ...
#  2018-08  0.0025  0.0025  0.0025
#  2018-09  0.0025  0.0025  0.0025
#  2018-10  0.0025  0.0025  0.0025
#  2018-11  0.0025  0.0025  0.0025
#  2018-12  0.0025  0.0025  0.0025
#
#  [228 rows x 3 columns]}

# %%
erk.run_cppi(risky_r)
# Out:
# {'wealth':                Steel          Fin         Beer
#  2000-01   984.380000   974.480000   987.320000
#  2000-02  1023.292876   931.167544   922.971256
#  2000-03  1047.555176   998.187296   924.835988
#  2000-04  1042.079009   973.927479   939.993701
#  2000-05  1007.137753  1001.460033   991.145489
#  ...              ...          ...          ...
#  2018-08  1078.784329  2461.732061  4155.508933
#  2018-09  1073.786842  2414.220632  4163.404400
#  2018-10   979.057951  2282.645608  4098.038951
#  2018-11   964.047446  2348.614066  4335.315406
#  2018-12   892.488571  2079.932617  3915.223343
#
#  [228 rows x 3 columns],
#  'risky_wealth':                Steel          Fin         Beer
#  2000-01   972.300000   955.800000   977.200000
#  2000-02  1038.805320   874.652580   863.453920
#  2000-03  1075.059626  1020.632096   864.576410
#  2000-04  1066.029125   977.255232   896.392822
#  2000-05  1013.580492  1026.704346  1002.794650
#  ...              ...          ...          ...
#  2018-08  1306.624224  3283.129665  4629.014147
#  2018-09  1297.869842  3219.765263  4637.809274
#  2018-10  1147.187153  3044.288056  4564.995669
#  2018-11  1112.771539  3132.267981  4829.308918
#  2018-12   948.303905  2773.936524  4361.348884
#
#  [228 rows x 3 columns],
#  'risk_budget':             Steel       Fin      Beer
#  2000-01  0.200000  0.200000  0.200000
#  2000-02  0.187306  0.179049  0.189726
#  2000-03  0.218210  0.140864  0.133234
#  2000-04  0.236317  0.198547  0.134982
#  2000-05  0.232304  0.178584  0.148930
#  ...           ...       ...       ...
#  2018-08  0.278101  0.667064  0.811065
#  2018-09  0.258425  0.675026  0.807484
#  2018-10  0.254973  0.668630  0.807850
#  2018-11  0.182888  0.649529  0.804785
#  2018-12  0.170165  0.659374  0.815469
#
#  [228 rows x 3 columns],
#  'risk_allocation':             Steel       Fin      Beer
#  2000-01  0.600000  0.600000  0.600000
#  2000-02  0.561917  0.537148  0.569177
#  2000-03  0.654630  0.422591  0.399702
#  2000-04  0.708951  0.595642  0.404945
#  2000-05  0.696912  0.535751  0.446791
#  ...           ...       ...       ...
#  2018-08  0.834304  1.000000  1.000000
#  2018-09  0.775274  1.000000  1.000000
#  2018-10  0.764920  1.000000  1.000000
#  2018-11  0.548664  1.000000  1.000000
#  2018-12  0.510496  1.000000  1.000000
#
#  [228 rows x 3 columns],
#  'm': 3,
#  'start': 1000,
#  'floor': 0.8,
#  'risky_r':           Steel     Fin    Beer
#  2000-01 -0.0277 -0.0442 -0.0228
#  2000-02  0.0684 -0.0849 -0.1164
#  2000-03  0.0349  0.1669  0.0013
#  2000-04 -0.0084 -0.0425  0.0368
#  2000-05 -0.0492  0.0506  0.1187
#  ...         ...     ...     ...
#  2018-08 -0.0323  0.0245 -0.0186
#  2018-09 -0.0067 -0.0193  0.0019
#  2018-10 -0.1161 -0.0545 -0.0157
#  2018-11 -0.0300  0.0289  0.0579
#  2018-12 -0.1478 -0.1144 -0.0969
#
#  [228 rows x 3 columns],
#  'safe_r':           Steel     Fin    Beer
#  2000-01  0.0025  0.0025  0.0025
#  2000-02  0.0025  0.0025  0.0025
#  2000-03  0.0025  0.0025  0.0025
#  2000-04  0.0025  0.0025  0.0025
#  2000-05  0.0025  0.0025  0.0025
#  ...         ...     ...     ...
#  2018-08  0.0025  0.0025  0.0025
#  2018-09  0.0025  0.0025  0.0025
#  2018-10  0.0025  0.0025  0.0025
#  2018-11  0.0025  0.0025  0.0025
#  2018-12  0.0025  0.0025  0.0025
#
#  [228 rows x 3 columns]}

# %%
erk.summary_stats(risky_r)
# Out:
#        Annualized ret  Annualized vol  Annualized sharp ratio  Skewness  \
# Steel       -0.002790        0.312368               -0.104972 -0.326334
# Fin          0.055166        0.192909                0.130456 -0.533218
# Beer         0.080598        0.138925                0.364213 -0.493545
#
#        Kortosis  Historical VaR(5%)  Cornish_Fisher VaR(5%)  Max Drawdown
# Steel  4.108106           -0.208117                0.150204     -0.758017
# Fin    4.951810           -0.132175                0.091273     -0.718465
# Beer   4.137348           -0.091442                0.063045     -0.271368

# %%
btr = erk.run_cppi(risky_r)
erk.summary_stats(btr['wealth'].pct_change().dropna())
# Out:
#        Annualized ret  Annualized vol  Annualized sharp ratio  Skewness  \
# Steel       -0.005167        0.174180               -0.201901 -1.995143
# Fin          0.040894        0.131678                0.082735 -0.946504
# Beer         0.075544        0.115462                0.394449 -0.669250
#
#         Kortosis  Historical VaR(5%)  Cornish_Fisher VaR(5%)  Max Drawdown
# Steel  16.959772           -0.130153                0.092148     -0.655198
# Fin     5.998215           -0.091621                0.065576     -0.549673
# Beer    4.719025           -0.074908                0.052951     -0.259582

# %%
btr = erk.run_cppi(risky_r)

# %%
tmi_rets = total_market_return
tmi_rets
# Out:
# 1926-07    0.031375
# 1926-08    0.028957
# 1926-09    0.005566
# 1926-10   -0.028504
# 1926-11    0.028039
#              ...
# 2018-08    0.036951
# 2018-09    0.002108
# 2018-10   -0.074292
# 2018-11    0.019003
# 2018-12   -0.092911
# Freq: M, Length: 1110, dtype: float64

# %%
btr = erk.run_cppi(tmi_rets['2007':])
ax = btr['wealth'].plot(figsize = (12,6),legend = False)
btr['risky_wealth'].plot(ax=ax,style = "k--",legend = False);

# %%
erk.summary_stats(btr['risky_wealth'].pct_change().dropna())
# Out:
#    Annualized ret  Annualized vol  Annualized sharp ratio  Skewness  Kortosis  \
# R        0.073411        0.150463                0.288517 -0.734939  4.460444
#
#    Historical VaR(5%)  Cornish_Fisher VaR(5%)  Max Drawdown
# R           -0.096315                0.071647     -0.499943

# %%
erk.summary_stats(btr['wealth'].pct_change().dropna())
# Out:
#    Annualized ret  Annualized vol  Annualized sharp ratio  Skewness  Kortosis  \
# R        0.069416        0.100381                0.392661 -0.588292  3.688794
#
#    Historical VaR(5%)  Cornish_Fisher VaR(5%)  Max Drawdown
# R           -0.062953                0.045709     -0.229683

# %%
ind_returns
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2018-08 -0.0038 -0.0186 -0.0543  0.0289 -0.0447  0.0254  0.0526  0.0446
# 2018-09 -0.0032  0.0019  0.0537 -0.0009 -0.0221  0.0107  0.0130  0.0199
# 2018-10  0.0102 -0.0157  0.0790 -0.1596 -0.0666 -0.0051 -0.1014 -0.0884
# 2018-11  0.0272  0.0579 -0.0843 -0.0065  0.0325  0.0644 -0.0099  0.0632
# 2018-12 -0.0973 -0.0969 -0.1580 -0.0824 -0.1535 -0.0557 -0.0728 -0.0840
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
# ...         ...     ...  ...     ...     ...     ...     ...     ...     ...
# 2018-08  0.0001  0.0380  ...  0.0295  0.0524  0.0993 -0.0034  0.0291  0.0366
# 2018-09 -0.0287 -0.0638  ...  0.0174 -0.0037 -0.0033 -0.0030  0.0105 -0.0148
# 2018-10 -0.1250 -0.2579  ... -0.0050 -0.0920 -0.0806 -0.0982 -0.0975 -0.0788
# 2018-11  0.0496  0.0292  ...  0.0254  0.0129 -0.0505  0.0822  0.0617  0.0318
# 2018-12 -0.0776 -0.1009  ... -0.0884 -0.0765 -0.0923 -0.0863 -0.1519 -0.1121
#
#           Rtail   Meals     Fin   Other
# 1926-07  0.0007  0.0187  0.0037  0.0520
# 1926-08 -0.0075 -0.0013  0.0446  0.0676
# 1926-09  0.0025 -0.0056 -0.0123 -0.0386
# 1926-10 -0.0220 -0.0411 -0.0516 -0.0849
# 1926-11  0.0652  0.0433  0.0224  0.0400
# ...         ...     ...     ...     ...
# 2018-08  0.0911  0.0364  0.0245  0.0299
# 2018-09  0.0061  0.0251 -0.0193  0.0116
# 2018-10 -0.1021 -0.0171 -0.0545 -0.0599
# 2018-11  0.0159  0.0616  0.0289  0.0348
# 2018-12 -0.0919 -0.0628 -0.1144 -0.0693
#
# [1110 rows x 30 columns]

# %%
btr = erk.run_cppi(ind_returns['2007':][['Steel','Fin','Beer']],drawdown = 0.25)

# %%
ind_returns['2007':]['Steel'].plot()
# Out:
# <AxesSubplot:>

# %%
ax = btr['wealth'].plot(figsize=(12,6))
btr['risky_wealth'].plot(ax=ax,style= 'k--');

# %%
erk.summary_stats(btr['risky_wealth'].pct_change().dropna())
# Out:
#        Annualized ret  Annualized vol  Annualized sharp ratio  Skewness  \
# Steel       -0.039660        0.306407               -0.227344 -0.459951
# Fin          0.027364        0.212204               -0.012423 -0.695200
# Beer         0.111554        0.127971                0.637286 -0.670797
#
#        Kortosis  Historical VaR(5%)  Cornish_Fisher VaR(5%)  Max Drawdown
# Steel  4.716169           -0.203837                0.152406     -0.758017
# Fin    4.556992           -0.149862                0.105823     -0.718465
# Beer   4.586059           -0.077388                0.056545     -0.271368

# %%
erk.summary_stats(btr['wealth'].pct_change().dropna())
# Out:
#        Annualized ret  Annualized vol  Annualized sharp ratio  Skewness  \
# Steel        0.003784        0.097073               -0.270066 -0.441089
# Fin          0.041975        0.085028                0.140833 -0.355163
# Beer         0.084375        0.086263                0.630340 -0.744111
#
#        Kortosis  Historical VaR(5%)  Cornish_Fisher VaR(5%)  Max Drawdown
# Steel  5.147723           -0.066991                0.047412     -0.248059
# Fin    4.095967           -0.054111                0.038370     -0.243626
# Beer   4.507819           -0.051189                0.037969     -0.161186

# %% [markdown]
# # Random walk

# %%
def gbm0(n_years = 10, n_scenarios= 1000, mu = 0.07, sigma=0.15, steps_per_year=12, s_0 = 100):
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    xi = np.random.normal(size=(n_steps,n_scenarios))
    rets = mu*dt + sigma*np.sqrt(dt)*xi
    rets = pd.DataFrame(rets)
    prices = s_0*(1+rets).cumprod()
    return prices

# %%
 p = gbm(10,n_scenarios=3 )

# %%
p.shape
# Out:
# (120, 3)

# %%
p.head()
# Out:
#            0           1           2
# 0  91.667433  101.323399  104.956528
# 1  91.836162  106.999287  101.645461
# 2  91.230387  103.872641  107.492094
# 3  92.818688  102.032907  113.362484
# 4  96.765688  101.995150  111.115692

# %%
p.plot();

# %%
p= gbm(10,10000).plot(figsize=(12,6),legend=False)

# %%
def gbm0(n_years = 10, n_scenarios= 1000, mu = 0.07, sigma=0.15, steps_per_year=12, s_0 = 100):
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    xi = np.random.normal(size=(n_steps,n_scenarios))
    rets = mu*dt + sigma*np.sqrt(dt)*xi
    rets = pd.DataFrame(rets)
    prices = s_0*(1+rets).cumprod()
    return prices




def gbm(n_years = 10, n_scenarios= 1000, mu = 0.07, sigma=0.15, steps_per_year=12, s_0 = 100):
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    rets_plus_1 = np.random.normal(loc=(1+ mu*dt),scale=(sigma*np.sqrt(dt)) ,size=(n_steps,n_scenarios))
    prices = s_0*pd.DataFrame(rets_plus_1).cumprod()
    return prices

# %%
# %timeit gbm0(5,1000)
# Out:
# 2.09 ms ± 13.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit gbm1(5,1000)
# Out:
# 1.6 ms ± 11.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
gbm(10,20).plot(legend=False, figsize=(12,6));

# %%
def gbm(n_years = 10, n_scenarios= 1000, mu = 0.07, sigma=0.15, steps_per_year=12, s_0 = 100):
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    rets_plus_1 = np.random.normal(loc=(1+ mu*dt),scale=(sigma*np.sqrt(dt)) ,size=(n_steps,n_scenarios))
    rets_plus_1[0]=1
    prices = s_0*pd.DataFrame(rets_plus_1).cumprod()
    return prices

# %%
gbm(10,20).plot(legend=False, figsize=(12,6));

# %%
gbm(10,20)
# Out:
#              0           1           2           3           4           5   \
# 0    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1    100.010983  103.068117  100.428917  100.351793   99.183397  101.976435
# 2    101.809185   97.695687  107.626282   97.668561  108.606315  106.464993
# 3    101.367466  100.551860  107.792786   96.274929  108.170766  110.805525
# 4    101.802476  103.835778  110.107112   98.781866  108.170684  105.754569
# ..          ...         ...         ...         ...         ...         ...
# 115  126.495225  137.953208  126.536224  135.240224  264.878019  259.919526
# 116  123.236766  146.607225  130.705860  131.753937  250.713216  261.258503
# 117  119.202232  134.895871  129.302372  134.813940  243.995205  237.311740
# 118  116.033697  143.622275  129.282825  140.531324  236.688510  241.553524
# 119  111.606705  148.386292  122.941658  141.075492  248.452216  249.741170
#
#              6           7           8           9           10          11  \
# 0    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1     97.225143  109.749923   99.591545  100.984363  101.261669  104.275874
# 2     95.143369  113.390947  100.985825   98.150673  105.092134  100.785949
# 3     96.415288  120.853129  109.140051  101.522301  103.264305  104.614035
# 4     97.810540  123.876077  106.264222  106.066703  102.182176  110.694654
# ..          ...         ...         ...         ...         ...         ...
# 115  111.400225  245.699673  248.857284  235.535585  151.263630  162.199899
# 116  123.495081  245.279242  256.334735  224.831491  145.195323  179.880555
# 117  127.418730  234.946036  252.739993  221.723918  152.854244  167.359349
# 118  128.839730  215.403558  247.765863  209.011792  155.384532  178.264608
# 119  124.761535  222.682763  253.800898  205.317003  157.423502  178.965106
#
#              12          13          14          15          16          17  \
# 0    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1     99.858392   90.728427  105.512695  103.767990   97.363075  106.167615
# 2     92.110047   91.448074  104.107180  110.322163   93.695494  110.494451
# 3    100.763623   95.078554  101.396256  109.524410   93.476718  115.878101
# 4    103.874234   94.161722   97.889311  107.931316   99.670783  114.730759
# ..          ...         ...         ...         ...         ...         ...
# 115  112.884379  189.936177  165.391275  267.072845  172.594927  178.050487
# 116  117.847286  181.895831  165.581433  251.917806  169.783908  165.070959
# 117  119.809013  193.736799  167.208453  265.672717  168.555372  164.934154
# 118  115.576492  207.483693  158.353647  251.906635  169.438390  164.696248
# 119  104.771015  207.258469  162.268671  239.381870  164.295694  172.242072
#
#              18          19
# 0    100.000000  100.000000
# 1    102.761233  101.381750
# 2    105.822132   98.787969
# 3     99.450753  102.503090
# 4     96.678279   93.723918
# ..          ...         ...
# 115  394.036976  166.139717
# 116  371.468348  162.650640
# 117  366.172347  169.424577
# 118  344.127764  176.308397
# 119  338.443623  182.047943
#
# [120 rows x 20 columns]

# %%
import ipywidgets as widget
def squareit(n):
    return n*n
widget.interact(squareit, n =(0,100));
# Out:
# interactive(children=(IntSlider(value=50, description='n'), Output()), _dom_classes=('widget-interact',))

# %%
ax = erk.gbm(10,100,mu=0.1).plot(figsize=(12,6),legend = False)
ax.axhline(y = 100,marker="o",color="darkred",alpha=0.5);

# %%
erk.show_gbm(100,0.1,0.15)

# %%
def show_gbm(n_scenarios,mu,sigma):
    s_0=100
    prices = erk.gbm(n_scenarios=n_scenarios,mu=mu,sigma=sigma,s_0=s_0,prices=True)
    ax = prices.plot(legend=False,figsize=(12,5),linewidth=2,color="indianred")
    ax.axhline(y=s_0,ls=":",color="black") # set a horizontal line
    ax.set_ylim(top=400)# set the top value boundary
    #draw a dot at origin
    ax.plot(0,s_0,marker="o",color = "darkred")

# %%
show_gbm(20,0.1,0.15)

# %%
erk.gbm(n_scenarios=20,mu=0.1,sigma=0.15,s_0=100).plot();

# %%
import ipywidgets as widgets
from IPython .display import display
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
gbm_control = widgets.interactive(show_gbm,n_scenarios=(1,20,1),mu=(0,0.2,0.01),sigma=(0,.3,.01))

# %%
display(gbm_control);
# Out:
# interactive(children=(IntSlider(value=10, description='n_scenarios', max=20, min=1), FloatSlider(value=0.1, de…

# %%
def show_cppi(n_scenarios=50,mu=0.07,sigma=0.15,m=3,floor=0.,risk_free_rate=.03 ,y_max=100):
    start = 100
    sim_rets = erk.gbm(n_scenarios= n_scenarios, mu = mu, prices = False, sigma=sigma,steps_per_year=12)
    risk_rets = pd.DataFrame(sim_rets)
    
    btr = erk.run_cppi(risky_r=pd.DataFrame(risk_rets), start=start,floor=floor,risk_free_rate=risk_free_rate)
    wealth = btr['wealth']
    y_max = wealth.values.max()*y_max/100
    ax = wealth.plot(legend=False,alpha=0.5,color='indianred',figsize=(12,6))
    ax.axhline(y=start,ls=":",color="black")
    ax.axhline(y=start*floor,ls="--",color="red")
    ax.set_ylim(top=y_max)

cppi_control= widgets.interactive(show_cppi,n_scenarios=widgets.IntSlider(min=1,max=1000,step=5,value=50),
                                 mu = (0,+0.2,0.01),
                                 sigma=(0,.3,.05),
                                 floor=(0,2,.1),
                                 m = (1,5,.5),
                                 risk_free_rate=(0,.05,.01),
                                 y_max=widgets.IntSlider(min=0,max=100,step=1,value=100,
                                                           description="Zoom Y Axis")
                                 )     
display(cppi_control)
# Out:
# interactive(children=(IntSlider(value=50, description='n_scenarios', max=1000, min=1, step=5), FloatSlider(val…

# %%
import matplotlib.pyplot as plt

# %%
# Put a histogram near the previous chart

def show_cppi(n_scenarios=50,mu=0.07,sigma=0.15,m=3,floor=0.,risk_free_rate=.03 ,y_max=100):
    start = 100
    sim_rets = erk.gbm(n_scenarios= n_scenarios, mu = mu, prices = False, sigma=sigma,steps_per_year=12)
    risk_rets = pd.DataFrame(sim_rets)
    
    btr = erk.run_cppi(risky_r=pd.DataFrame(risk_rets), start=start,floor=floor,risk_free_rate=risk_free_rate)
    wealth = btr['wealth']
    y_max = wealth.values.max()*y_max/100
    terminal_wealth = wealth.iloc[-1]
    fig,(wealth_ax,hist_ax) = plt.subplots(nrows=1,ncols=2,sharey=True,gridspec_kw={'width_ratios':[2,2]},figsize=(24,6))
    plt.subplots_adjust(wspace=0.0)
    
    
    wealth.plot(legend=False,alpha=0.5,color='indianred',figsize=(12,6))
    wealth_ax.axhline(y=start,ls=":",color="black")
    wealth_ax.axhline(y=start*floor,ls="--",color="red")
    wealth_ax.set_ylim(top=y_max)
    
    terminal_wealth.plot.hist(ax=hist_ax,bins=50,ec="w",fc="indianred",orientation="horizontal")
    hist_ax.axhline(y=start,ls=":",color="black")

cppi_control= widgets.interactive(show_cppi,n_scenarios=widgets.IntSlider(min=1,max=1000,step=5,value=50),
                                 mu = (0,+0.2,0.01),
                                 sigma=(0,.3,.05),
                                 floor=(0,2,.1),
                                 m = (1,5,.5),
                                 risk_free_rate=(0,.05,.01),
                                 y_max=widgets.IntSlider(min=0,max=100,step=1,value=100,
                                                           description="Zoom Y Axis")
                                 )     
display(cppi_control)
# Out:
# interactive(children=(IntSlider(value=50, description='n_scenarios', max=1000, min=1, step=5), FloatSlider(val…

# %%
def show_cppi(n_scenarios=50,mu=0.07,sigma=0.15,m=3,floor=0.,risk_free_rate=.03 ,y_max=100):
    start = 100
    sim_rets = erk.gbm(n_scenarios= n_scenarios, mu = mu, prices = False, sigma=sigma,steps_per_year=12)
    risk_rets = pd.DataFrame(sim_rets)
    
    btr = erk.run_cppi(risky_r=pd.DataFrame(risk_rets), start=start,floor=floor,risk_free_rate=risk_free_rate)
    wealth = btr['wealth']
    y_max = wealth.values.max()*y_max/100
    terminal_wealth = wealth.iloc[-1]
    tw_mean=terminal_wealth.mean()
    tw_median = terminal_wealth.median()
    failsure_mask = np.less(terminal_wealth, start*floor)
    n_failsures = failsure_mask.sum()
    p_fail = n_failsures / n_scenarios
    
    e_shortfall = np.dot(tv-start*floor, failsure_mask)/n_failsures if n_failsures>0 else 0.0 # 点乘， else e_shaorfall is 0
   




    fig,(wealth_ax,hist_ax) = plt.subplots(nrows=1,ncols=2,sharey=True,gridspec_kw={'width_ratios':[3,2]},figsize=(24,6))
    plt.subplots_adjust(wspace=0.0)
    
    
    wealth.plot(legend=False,alpha=0.5,color='indianred',figsize=(12,6))
    wealth_ax.axhline(y=start,ls=":",color="black")
    wealth_ax.axhline(y=start*floor,ls="--",color="red")
    wealth_ax.set_ylim(top=y_max)
    
    terminal_wealth.plot.hist(ax=hist_ax,bins=50,ec="w",fc="indianred",orientation="horizontal")
    hist_ax.axhline(y=start,ls=":",color="black")
    hist_ax.axhline(y=tw_mean,ls=":",color="blue")
    hist_ax.axhline(y=tw_median,ls=":",color="purple")
    
    hist_ax.annotate(f"Mean:$ {int(tw_mean)}",xy=(.7,.9),xycoords="axes fraction",fontsize=24)
    hist_ax.annotate(f"Median:$ {int(tw_median)}",xy=(.7,.85),xycoords="axes fraction",fontsize=24)

    if(floor>0.01):
        hist_ax.axhline(y=start*floor,ls="--",color="red",linewidth=3)
        hist_ax.annotate(f"Violation: {n_failsures} ({p_fail*100:2.2f}%)\nE(shortfall=${e_shortfall:2.2f}"
                         ,xy=(.7,.7),xycoords="axes fraction",fontsize=24)      
                         

cppi_control= widgets.interactive(show_cppi,n_scenarios=widgets.IntSlider(min=1,max=1000,step=5,value=50),
                                 mu = (0,+0.2,0.01),
                                 sigma=(0,.3,.05),
                                 floor=(0,2,.1),
                                 m = (1,5,.5),
                                 risk_free_rate=(0,.05,.01),
                                 y_max=widgets.IntSlider(min=0,max=100,step=1,value=100,
                                                           description="Zoom Y Axis")
                                 )     
display(cppi_control)
# Out:
# interactive(children=(IntSlider(value=50, description='n_scenarios', max=1000, min=1, step=5), FloatSlider(val…

# %%
def df_cppi(n_scenarios,floor,risk_free_rate=0.05,mu=0.07,sigma=0.15,m=3, y_max=100):
    start = 100
    sim_rets = erk.gbm(n_scenarios= n_scenarios, mu = mu, prices = False, sigma=sigma,steps_per_year=12)
    risk_rets = pd.DataFrame(sim_rets)
    
    btr = erk.run_cppi(risky_r=pd.DataFrame(risk_rets), start=start,floor=floor,risk_free_rate=risk_free_rate)
    wealth = btr['wealth']
    y_max = wealth.values.max()*y_max/100
    terminal_wealth = wealth.iloc[-1]
    df = terminal_wealth.min()
    return df

# %%
a=(500,550,600,650,700,750,800,850,900,950,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2050)
b=np.linspace(0,1,20)
b = tuple(b)
b
# Out:
# (0.0,
#  0.05263157894736842,
#  0.10526315789473684,
#  0.15789473684210525,
#  0.21052631578947367,
#  0.2631578947368421,
#  0.3157894736842105,
#  0.3684210526315789,
#  0.42105263157894735,
#  0.47368421052631576,
#  0.5263157894736842,
#  0.5789473684210527,
#  0.631578947368421,
#  0.6842105263157894,
#  0.7368421052631579,
#  0.7894736842105263,
#  0.8421052631578947,
#  0.894736842105263,
#  0.9473684210526315,
#  1.0)

# %%
x = []
for i in b:
    a = df_cppi(800,i)
    x.append(a)

# %%
pd.DataFrame(x).plot();
